# %%
class student:
    def __init__(self, name, rollno, marks):
        self.name = name
        self.rollno = rollno
        self.marks = marks
        
    def display_details(self):
        print("-"*20)
        print(f"name :{self.name}")
        print(f"rollno :{self.rollno}")
        print(f"marks :{self.marks}")
        
#accepting for two students
students = []
for i in range(1, 3):
    print(f"\n enter details for student{i}: ")
    name = input("enter name: ")
    roll = input("enter roll number: ")
    marks = input("enter marks: ")
    students.append(student(name, roll, marks))
    
#displaying details
print("\n -- student records --")
for s in students:
    s.display_details()
# Out:
#  enter details for student1:
# enter name: madhura
# enter roll number: 11
# enter marks: 99
#
#  enter details for student2:
# enter name: mudra
# enter roll number: 12
# enter marks: 99
#
#  -- student records --
# --------------------
# name :madhura
# rollno :11
# marks :99
# --------------------
# name :mudra
# rollno :12
# marks :99

# %%
class book:
    def __init__ (self, title, author, price):
        self.title = title
        self.author = author
        self.price = price
        
    def show_book_info(self):
        print(f"\nbook: '{self.title}' by {self.author}")
        print(f" price: ${self.price}")
        
print("--enter book details --")
t = input("enter title: ")
a = input("enter author: ")
p = input("enter price: ")

my_book = book(t, a, p)
my_book.show_book_info()
# Out:
# --enter book details --
# enter title: manifestation
# enter author: madhura
# enter price: 222
#
# book: 'manifestation' by madhura
#  price: $222

# %%
class calculator:
    def __init__(self, a, b):
        self.num1 = a
        self.num2 = b
        
    def add(self):
        return self.num1 + self.num2
    
    def sub(self):
        return self.num1 - self.num2
    
    def product(self):
        return self.num1 * self.num2
    
    def divide(self):
        if self.num2 != 0:
            return self.num1 / self.num2
        else:
            return "error! division by zero"
        
print("\n simple calculator")
n1 = float(input("enter first number"))
n2 = float(input("enter second number"))

calc = calculator(n1, n2)

print("\n results for {n1} and {n2}: ")
print (f"addition: {calc.add()}")
print (f"subtraction: {calc.sub()}")
print (f"multiplication: {calc.product()}")
print (f"division: {calc.divide()}")
# Out:
#  simple calculator
# enter first number1
# enter second number2
#
#  results for {n1} and {n2}:
# addition: 3.0
# subtraction: -1.0
# multiplication: 2.0
# division: 0.5

# %%
class employee:
    def __init__(self, emp_id, name, base_salary):
        self.emp_id = emp_id
        self.name = name
        self.base_salary = base_salary
        
    def display_info(self):
        print(f"[{self.emp_id}] name: {self.name} | base salary: ${self.base_salary}")
             
    def work(self):
              return"performing general duties"
              
              
class developer(employee):
              def __init__(self, emp_id, name, base_salary, language):
                   super ().__init__(emp_id, name, base_salary)
                   self.language = language
              
              def work(self):
                  return f"writing code in {self.language}"
              
class tester(employee):
              def __init__(self, emp_id, name, base_salary, tool):
                super().__init__(emp_id, name, base_salary)
                self.tool = tool
              
              def work(self):
                  return f"testing software using {self.tool}"
              
class manager(employee):
              def __init__(self, emp_id, name, base_salary, team_size):
                   super().__init__(emp_id, name, base_salary)
                   self.team_size = team_size
              
              def work(self):
                   return f"managing a team of {self.team_size} employees"
              
dev = developer(101, "alice", 80000, "python")
test = tester(102, "bob", 65000, "selenium")
mgr = manager(103, "charlie", 95000, 10)
              
employees = [dev, test, mgr]
              
print(" employees task list  ")

for emp in employees:
    emp.display_info()
    print(f"task: {emp.work()}\n")
# Out:
#  employees task list
# [101] name: alice | base salary: $80000
# task: writing code in python
#
# [102] name: bob | base salary: $65000
# task: testing software using selenium
#
# [103] name: charlie | base salary: $95000
# task: managing a team of 10 employees

# %%
class atm:
    def __init__ (self,pin):
        self.__pin = pin
        
    def validate_pin(self, entered_pin):
        """public method to check the pin"""
        if entered_pin == self.__pin:
            print("access granted! welcome to your account")
            return True
        else:
            print("access denied! incorrect pin")
            return False
        
my_atm = atm("1234")
user_input = input("please enter your 4 digit pin: ")
my_atm.validate_pin(user_input)
# Out:
# please enter your 4 digit pin: 1234
# access granted! welcome to your account
# True

# %%
class user:
    """base class for all system users"""
    def __init__(self,name,phone):
        self.name = name
        self.phone = phone
        
    def display_profile(self):
        print(f"user: {self.name} | phone: {self.phone}")
        
class customer(user):
    """derived class representing a person placing orders"""
    def __init__(self, name, phone, address):
        super().__init__(name, phone)
        self.address = address
        
    def show_customer_info(self):
        self.display_profile()
        print(f"delivery address: {self.address}")
        
class deliveryperson(user):
    """derived class representing the person delivering orders"""
    def __init__(self, name, phone, vehicle_number):
        super().__init__(name, phone)
        self.vehicle_number = vehicle_number
        
    def show_delivery_info(self):
        super().display_profile()
        print(f"vehicle no: {self.vehicle_number}")
        
print("  creating customer  ")
cust = customer("arjun","8493846573","123 green avenue pune" )
cust.show_customer_info()

print("  creating delivery person  ")
rider  = deliveryperson("suresh","4747859484","mh12 ab 1234" )
rider.show_delivery_info()
# Out:
#   creating customer
# user: arjun | phone: 8493846573
# delivery address: 123 green avenue pune
#   creating delivery person
# user: suresh | phone: 4747859484
# vehicle no: mh12 ab 1234

# %%
class university:
    def university_info(self, uni_name):
        self.uni_name = uni_name
        print(f"university: {self.uni_name}")
        
class college(university):
    def college_info(self, college_name):
        self.college_name = college_name
        print(f"college: {self.college_name}")
    
class student(college):
    def student_info(self, student_name):
        self.student_name = student_name
        print(f"student.name: {self.student_name}")
        
s1 = student()
print("accessing the methods accross the chain ")

s1.university_info(" SPPU ")
s1.college_info(" SP ")
s1.student_info(" madhura ")
# Out:
# accessing the methods accross the chain
# university:  SPPU
# college:  SP
# student.name:  madhura
